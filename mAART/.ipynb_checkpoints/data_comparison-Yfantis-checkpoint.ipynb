# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
G = 6.67*10**-11
c = 2.99792458*10**8
SM = 1.988435*10**30 
MM87 = 6.2*10**9*SM;
MSGR = 4.3*10**6*SM;
MBH=MSGR
secondinM=1/(MBH*G/c**3)
M_in_seconds=1/secondinM # [M in seconds]
t_from_M_to_hours = 1*M_in_seconds/3600
t_from_hours_to_M = 1*3600/M_in_seconds

# %%
# Find limits for QU loop plots

def auto_limits(x1, y1, x2, y2, padding_factor=0.25, default_lim=(-0.2, 0.2)):
    """
    Automatically calculate xlim and ylim values for two sets of data with divergence handling.
    
    Parameters:
    x1 (array-like): x-coordinate data for first set
    y1 (array-like): y-coordinate data for first set
    x2 (array-like): x-coordinate data for second set
    y2 (array-like): y-coordinate data for second set
    padding_factor (float): percentage of range to add as padding (default: 0.25)
    default_lim (tuple): fallback limits when data is divergent (default: (-0.2, 0.2))
    
    Returns:
    tuple: (xlim, ylim) where each is a (min, max) tuple
    """
    # Convert to numpy arrays and take real parts
    x1 = np.asarray(x1).real
    y1 = np.asarray(y1).real
    x2 = np.asarray(x2).real
    y2 = np.asarray(y2).real
    
    def calculate_lim(data):
        # Handle empty data
        if len(data) == 0:
            return default_lim
        
        # Handle constant values
        if np.all(data == data[0]):
            center = data[0]
            return (center - 1, center + 1)  # Symmetric range around single value
        
        # Handle infinite or NaN values
        if not np.all(np.isfinite(data)):
            return default_lim
            
        # Calculate regular limits with padding
        data_min, data_max = np.nanmin(data), np.nanmax(data)
        data_range = data_max - data_min
        
        # Handle extremely large ranges (divergent cases)
        if data_range > 1e6:  # Adjust threshold as needed
            return default_lim
            
        padding = data_range * padding_factor
        return (data_min - padding, data_max + padding)
    
    # Combine x data from both sets for overall xlim
    xlim = calculate_lim(np.concatenate([x1, x2]))
    
    # Combine y data from both sets for overall ylim
    ylim = calculate_lim(np.concatenate([y1, y2]))
    
    return xlim, ylim

# %%
# Data cropped to 3 "turns"

load_data = np.loadtxt("./experimentalDataQU_t_Q_U_cropped3turns.txt",unpack=True)
t_load,Q_load,U_load=load_data

# %%
# Data cropped to 2 "turns"
load_data_2turns = np.loadtxt("./experimentalDataQU_t_Q_U_cropped2turns.txt",unpack=True)
t_load_2turns,Q_load_2turns,U_load_2turns=load_data_2turns

# %%
# Data cropped to match Yfantis et al. 2023

load_data_yfantis = np.loadtxt("./experimentalDataQU_t_Q_U_croppedYfantis.txt",unpack=True)
t_data_yfantis,Q_data_yfantis,U_data_yfantis=load_data_yfantis

# %%
plt.scatter(Q_data_yfantis,U_data_yfantis,s=2)

# %%
# !python3 runQU.py
# Out:
# Thanks for using mAART
# Copyright (C) 2026, P. Ruales, A. Cardenas-Avendano, D. Gates
#
# Computing the lensing bands
# Number of points in the n=0 grid  9000000
# Number of points in the n=1 grid  900
# Number of points in the n=2 grid  900
# File  ./Results/LensingBands_a_0.870000_i_0.372279.h5  created.
# Ray-tracing
# Reading file:  ./Results/LensingBands_a_0.870000_i_0.372279.h5
# Analytical ray-tracing of the n=0 band points
# Analytical ray-tracing of the n=1 band points
# Analytical ray-tracing of the n=2 band points
# File  ./Results/Rays_a_0.870000_i_0.372279.h5  created.
#
# A total of 9001800 photons were ray-traced
# Reading file:  ./Results/Rays_a_0.870000_i_0.372279.h5
# Drawing QULoops
# Success!

# %%
# Model to fit as Yfantis

load_model_yfantis = np.loadtxt("./QU_data/i21.33_s0.87_B(1.0,0.0,0.0)_subkep_1.0_betar_1.0_betaphi_0.86_rinit_10.88_phiinit_0.0_gfactor_2_QUdata.txt",unpack=True)
t_model_yfantis,Q_model_yfantis,U_model_yfantis=load_model_yfantis
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[136], line 3
#       1 # Model to fit as Yfantis
# ----> 3 load_model_yfantis = np.loadtxt("./QU_data/i21.33_s0.87_B(0.0,1.0,0.0)_subkep_1.0_betar_1.0_betaphi_0.86_rinit_10.88_phiinit_0.0_gfactor_2_QUdata.txt",unpack=True)
#       4 t_model_yfantis,Q_model_yfantis,U_model_yfantis=load_model_yfantis
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
# ...

# %%
load_model_maciek = np.loadtxt("./QU_data/i22_s0.02_B(0.0,1.0,0.0)_subkep_1.0_betar_1.0_betaphi_1.0_rinit_11.0_phiinit_0.0_gfactor_2_QUdata.txt",unpack=True)
t_model_maciek,Q_model_maciek,U_model_maciek=load_model_maciek

# %%
plt.scatter(Q_model_maciek+0.045,(U_model_maciek-0.14))
plt.scatter(Q_load_2turns,U_load_2turns,s=2)

# %%
plt.scatter(Q_model_yfantis,U_model_yfantis,s=3)
plt.scatter(Q_data_yfantis,U_data_yfantis,s=2)

# %%
load_model_result_2turns = np.loadtxt("./QU_data/i20_s0.7_B(0.089107,0.59343,0.135083)_subkep_1.117014_betar_0.943011_betaphi_0.973262_rinit_14.513706_phiinit_0.297246_gfactor_3.156199_QUdata.txt",unpack=True)
t_model_2turns,Q_model_2turns,U_model_2turns=load_model_result_2turns

# %%
#13000 steps

load_model_result_2turns = np.loadtxt("./QU_data/i20_s0.7_B(-0.123544,-0.85295,-0.188062)_subkep_1.029128_betar_0.944483_betaphi_1.048171_rinit_14.354883_phiinit_0.290948_gfactor_3.043061_QUdata.txt",unpack=True)
t_model_2turns,Q_model_2turns,U_model_2turns=load_model_result_2turns

# %%
load_model_result = np.loadtxt("./QU_data/i20_s0.496459_B(0.089811,0.972364,0.351479)_betar_0.954509_betaphi_1.089719_rinit_13.787857_phiinit_0.003642_QUdata.txt",unpack=True)
t_model,Q_model,U_model=load_model_result

# %%
load_model_result2 = np.loadtxt("./QU_data/i20_s0.861546_B(-0.94539,0.746351,0.373038)_betar_0.96579_betaphi_0.310463_rinit_10.102982_phiinit_0.048186_QUdata.txt",unpack=True)
t_model2,Q_model2,U_model2=load_model_result2

# %%
load_model_result3 = np.loadtxt("./QU_data/i20_s0.7_B(0.075493,0.954042,0.266958)_subkep_0.848962_betar_0.955865_betaphi_1.017525_rinit_12.382305_phiinit_0.004122_gfactor_2.661114_QUdata.txt",unpack=True)
t_model3,Q_model3,U_model3=load_model_result3

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,U_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
plt.scatter(t_model,U_model,s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3m', '\n70.6m', '\n105.8m', '\n141.1m', '\n176.4m', '\n211.7m'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,U_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
plt.scatter(t_model2,U_model2,s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3m', '\n70.6m', '\n105.8m', '\n141.1m', '\n176.4m', '\n211.7m'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,U_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
plt.scatter(t_model3,U_model3,s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min', '\n176.4min', '\n211.7min'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
t_load_2turns*t_load_2turns
# Out:
# array([  0.        ,   0.85948216,   1.04997425,   1.33798015,
#          1.52847222,   1.71896431,   1.90945641,   2.19746231,
#          2.3879544 ,   2.57844647,   3.62842072,   3.91642662,
#          4.10691872,   4.29741081,   4.4879029 ,   4.77590878,
#          4.96640087,   5.15689297,   5.34738506,   6.01637512,
#          6.20686722,   6.49487312,   6.68536522,   6.87585728,
#          7.06634937,   7.35435528,   7.54484737,   7.73533947,
#          8.59482162,   9.45430378,  10.31378596,  11.17326809,
#         12.03275028,  12.22324234,  12.51124827,  12.70174034,
#         12.89223246,  13.08272453,  13.3707304 ,  13.56122252,
#         13.75171459,  14.42070465,  14.61119677,  14.80168884,
#         15.08969477,  15.28018678,  15.4706789 ,  15.66117102,
#         15.9491769 ,  16.52065315,  17.18964327,  17.38013534,
#         17.66814121,  19.57759759,  19.76808971,  19.95858184,
#         20.24658771,  20.43707983,  20.6275719 ,  20.81806396,
# ...

# %%
plt.plot(t_model_2turns,Q_model_2turns)
plt.scatter(t_load_2turns,Q_load_2turns)

# %%
maxval=1800

plt.scatter(Q_model_maciek+0.045,(U_model_maciek-0.14))
plt.scatter(Q_model_2turns[:maxval],U_model_2turns[:maxval],s=2)
plt.scatter(Q_load_2turns,U_load_2turns,s=2)

# %%
timemask = np.where(t_model_2turns<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load_2turns * t_from_M_to_hours

sc=plt.scatter(t_load_2turns,U_load_2turns,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load_2turns,U_load_2turns,Q_load_2turns,U_load_2turns)
plt.scatter(t_model_2turns[timemask],U_model_2turns[timemask],s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,Q_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
plt.scatter(t_model,Q_model,s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Qvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3m', '\n70.6m', '\n105.8m', '\n141.1m', '\n176.4m', '\n211.7m'])


# filename = f"./QvsT.png"
# plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,Q_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
plt.scatter(t_model2,Q_model2,s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Qvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3m', '\n70.6m', '\n105.8m', '\n141.1m', '\n176.4m', '\n211.7m'])


# filename = f"./QvsT.png"
# plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,Q_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
plt.scatter(t_model3,Q_model3,s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Qvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min', '\n176.4min', '\n211.7min'])


# filename = f"./QvsT.png"
# plt.savefig(filename,dpi=300)

# %%
timemask = np.where(t_model_2turns<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load_2turns * t_from_M_to_hours

sc=plt.scatter(t_load_2turns,Q_load_2turns,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load_2turns,U_load_2turns,Q_load_2turns,U_load_2turns)
plt.scatter(t_model_2turns[timemask],Q_model_2turns[timemask],s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Qvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min'])


# filename = f"./QvsT.png"
# plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(Q_load,U_load,c=t_load,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
ax.scatter(Q_model,U_model,s=2,color='k')

x0, y0 = Q_load[0], U_load[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [M]")
cbar.set_ticks(np.arange(t_load[0], t_load[-1], 100))
cbar.set_ticklabels([f"{t}" for t in np.arange(t_load[0], t_load[-1], 100)])

# Use twinx() for a vertical colorbar, twiny() for a horizontal one
cax2 = cbar.ax.twiny()

# 2. Set the limits of the new axis
# The limits must correspond to the data range for the secondary labels
cax2.set_xlim(cbar.ax.get_xlim()) # Match the primary axis limits

# 3. Set custom ticks and labels for the second axis
secondary_ticks = [100, 200, 300, 400, 500, 600] 
secondary_labels = ['35.3', '70.6', '105.8', '141.1', '176.4', '211.7']
cax2.set_xticks(secondary_ticks)
cax2.set_xticklabels(secondary_labels)
cax2.set_xlabel('[minutes]') # Add a label for the second axis

# Optional: Adjust the position of the new labels
cax2.yaxis.set_ticks_position('left')
cax2.yaxis.set_label_position('left')

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim[0]-0.04,ylim[1])
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr QU Loop")


# filename = f"./QU.png"
# plt.savefig(filename,dpi=300)
# Out:
# Text(0.5, 1.0, 'ALMA dataset 11Apr QU Loop')

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(Q_load,U_load,c=t_load,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
ax.scatter(Q_model2,U_model2,s=2,color='k')

x0, y0 = Q_load[0], U_load[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [M]")
cbar.set_ticks(np.arange(t_load[0], t_load[-1], 100))
cbar.set_ticklabels([f"{t}" for t in np.arange(t_load[0], t_load[-1], 100)])

# Use twinx() for a vertical colorbar, twiny() for a horizontal one
cax2 = cbar.ax.twiny()

# 2. Set the limits of the new axis
# The limits must correspond to the data range for the secondary labels
cax2.set_xlim(cbar.ax.get_xlim()) # Match the primary axis limits

# 3. Set custom ticks and labels for the second axis
secondary_ticks = [100, 200, 300, 400, 500, 600] 
secondary_labels = ['35.3', '70.6', '105.8', '141.1', '176.4', '211.7']
cax2.set_xticks(secondary_ticks)
cax2.set_xticklabels(secondary_labels)
cax2.set_xlabel('[minutes]') # Add a label for the second axis

# Optional: Adjust the position of the new labels
cax2.yaxis.set_ticks_position('left')
cax2.yaxis.set_label_position('left')

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim[0]-0.04,ylim[1])
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr QU Loop")


# filename = f"./QU.png"
# plt.savefig(filename,dpi=300)
# Out:
# Text(0.5, 1.0, 'ALMA dataset 11Apr QU Loop')

# %%
fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(Q_load,U_load,c=t_load,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)
ax.scatter(Q_model3,U_model3,s=2,color='k')

x0, y0 = Q_load[0], U_load[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [M]")
cbar.set_ticks(np.arange(t_load[0], t_load[-1], 100))
cbar.set_ticklabels([f"{t}" for t in np.arange(t_load[0], t_load[-1], 100)])

# Use twinx() for a vertical colorbar, twiny() for a horizontal one
cax2 = cbar.ax.twiny()

# 2. Set the limits of the new axis
# The limits must correspond to the data range for the secondary labels
cax2.set_xlim(cbar.ax.get_xlim()) # Match the primary axis limits

# 3. Set custom ticks and labels for the second axis
secondary_ticks = [100, 200, 300, 400, 500, 600] 
secondary_labels = ['35.3', '70.6', '105.8', '141.1', '176.4', '211.7']
cax2.set_xticks(secondary_ticks)
cax2.set_xticklabels(secondary_labels)
cax2.set_xlabel('[minutes]') # Add a label for the second axis

# Optional: Adjust the position of the new labels
cax2.yaxis.set_ticks_position('left')
cax2.yaxis.set_label_position('left')

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim[0]-0.04,ylim[1])
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr QU Loop")


# filename = f"./QU.png"
# plt.savefig(filename,dpi=300)
# Out:
# Text(0.5, 1.0, 'ALMA dataset 11Apr QU Loop')

# %%
timemask = np.where(t_model_2turns<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load_2turns * t_from_M_to_hours

sc=plt.scatter(Q_load_2turns,U_load_2turns,c=t_load_2turns,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load_2turns,U_load_2turns,Q_load_2turns,U_load_2turns)
ax.scatter(Q_model_2turns[timemask],U_model_2turns[timemask],s=2,color='k')

x0, y0 = Q_load_2turns[0], U_load_2turns[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [M]")
cbar.set_ticks(np.arange(t_load_2turns[0], t_load_2turns[-1], 100))
cbar.set_ticklabels([f"{t}" for t in np.arange(t_load_2turns[0], t_load_2turns[-1], 100)])

# Use twinx() for a vertical colorbar, twiny() for a horizontal one
cax2 = cbar.ax.twiny()

# 2. Set the limits of the new axis
# The limits must correspond to the data range for the secondary labels
cax2.set_xlim(cbar.ax.get_xlim()) # Match the primary axis limits

# 3. Set custom ticks and labels for the second axis
secondary_ticks = [100, 200, 300, 400] 
secondary_labels = ['35.3', '70.6', '105.8', '141.1']
cax2.set_xticks(secondary_ticks)
cax2.set_xticklabels(secondary_labels)
cax2.set_xlabel('[minutes]') # Add a label for the second axis

# Optional: Adjust the position of the new labels
cax2.yaxis.set_ticks_position('left')
cax2.yaxis.set_label_position('left')

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim[0]-0.04,ylim[1])
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr QU Loop")


# filename = f"./QU.png"
# plt.savefig(filename,dpi=300)
# Out:
# Text(0.5, 1.0, 'ALMA dataset 11Apr QU Loop')

# %%
fig, ax = plt.subplots(figsize=[6,6])

load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(Q_load,U_load,c=t_load,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)

x0, y0 = Q_load[0], U_load[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [M]")
cbar.set_ticks(np.arange(t_load[0], t_load[-1], 100))
cbar.set_ticklabels([f"{t}" for t in np.arange(t_load[0], t_load[-1], 100)])

# Use twinx() for a vertical colorbar, twiny() for a horizontal one
cax2 = cbar.ax.twiny()

# 2. Set the limits of the new axis
# The limits must correspond to the data range for the secondary labels
cax2.set_xlim(cbar.ax.get_xlim()) # Match the primary axis limits

# 3. Set custom ticks and labels for the second axis
secondary_ticks = [100, 200, 300, 400, 500, 600] 
secondary_labels = ['35.3', '70.6', '105.8', '141.1', '176.4', '211.7']
cax2.set_xticks(secondary_ticks)
cax2.set_xticklabels(secondary_labels)
cax2.set_xlabel('[minutes]') # Add a label for the second axis

# Optional: Adjust the position of the new labels
cax2.yaxis.set_ticks_position('left')
cax2.yaxis.set_label_position('left')

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim[0]-0.04,ylim[1])
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr QU Loop")


filename = f"./QU.png"
plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(Q_load,U_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)

x0, y0 = Q_load[0], U_load[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr")


filename = f"./QU_time_in_Hrs.png"
plt.savefig(filename,dpi=300)

# %%
for x in (100,200,300,400,500,600):
    xyz=x*t_from_M_to_hours*60
    print(xyz)
# Out:
# 35.27705557101755
# 70.5541111420351
# 105.83116671305265
# 141.1082222840702
# 176.38527785508774
# 211.6623334261053

# %%
fig, ax = plt.subplots(figsize=[6,6])

load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,U_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3m', '\n70.6m', '\n105.8m', '\n141.1m', '\n176.4m', '\n211.7m'])


filename = f"./UvsT.png"
plt.savefig(filename,dpi=300)

# %%
fig, ax = plt.subplots(figsize=[6,6])

load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
t_load,Q_load,U_load=load_data
timeInHrs = t_load * t_from_M_to_hours

sc=plt.scatter(t_load,Q_load,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load,U_load,Q_load,U_load)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Qvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400, 500, 600], labels=['\n35.3m', '\n70.6m', '\n105.8m', '\n141.1m', '\n176.4m', '\n211.7m'])


filename = f"./QvsT.png"
plt.savefig(filename,dpi=300)

# %%
timemask = np.where(t_model_maciek<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load_2turns * t_from_M_to_hours

sc=plt.scatter(t_load_2turns,U_load_2turns,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load_2turns,U_load_2turns,Q_load_2turns,U_load_2turns)
plt.scatter(t_model_maciek[timemask],U_model_maciek[timemask],s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
timemask = np.where(t_model_maciek<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load_2turns * t_from_M_to_hours

sc=plt.scatter(t_load_2turns,Q_load_2turns,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load_2turns,U_load_2turns,Q_load_2turns,U_load_2turns)
plt.scatter(t_model_maciek[timemask],Q_model_maciek[timemask],s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
def rotate_points(x, y, angle_degrees, center=(0, 0)):
    """
    Rotate points around a center point
    
    Parameters:
    x, y: arrays of coordinates
    angle_degrees: rotation angle in degrees
    center: (cx, cy) point to rotate around
    """
    cx, cy = center
    angle_rad = np.radians(angle_degrees)
    
    # Translate points to origin
    x_translated = x - cx
    y_translated = y - cy
    
    # Apply rotation
    x_rotated = x_translated * np.cos(angle_rad) - y_translated * np.sin(angle_rad)
    y_rotated = x_translated * np.sin(angle_rad) + y_translated * np.cos(angle_rad)
    
    # Translate back
    x_final = x_rotated + cx
    y_final = y_rotated + cy
    
    return x_final, y_final

# %%
Q_rotated, U_rotated = rotate_points(Q_model_yfantis,U_model_yfantis,53,center=(0.045,-0.16))

# %%
# Q_rot, U_rot = rotate_points(Q_model_maciek,U_model_maciek,0)

# %%
timemask = np.where(t_model_maciek<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_data_yfantis * t_from_M_to_hours

sc=plt.scatter(t_data_yfantis,U_data_yfantis,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_data_yfantis,U_data_yfantis,Q_data_yfantis,U_data_yfantis)
plt.scatter(t_model_maciek[timemask]-27,U_rotated[timemask],s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(ylim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
timemask = np.where(t_model_maciek<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_data_yfantis * t_from_M_to_hours

sc=plt.scatter(t_data_yfantis,Q_data_yfantis,c=timeInHrs,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_data_yfantis,U_data_yfantis,Q_data_yfantis,U_data_yfantis)
plt.scatter(t_model_maciek[timemask]-27,Q_rotated[timemask],s=2,color='k')

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [hrs]")
cbar.set_ticks(np.arange(timeInHrs[0], timeInHrs[-1], 0.5))
cbar.set_ticklabels([f"{t}" for t in np.arange(timeInHrs[0], timeInHrs[-1], 0.5)])

# Plot configuration
ax.set_ylim(xlim)
ax.set_xlabel("Time [M]", fontsize=12)
ax.set_ylabel("Q", fontsize=12)
ax.grid(alpha=0.2)
ax.set_title("ALMA dataset 11Apr Uvst")
sec = ax.secondary_xaxis(location=0.9)
sec.set_xticks([100, 200, 300, 400], labels=['\n35.3min', '\n70.6min', '\n105.8min', '\n141.1min'])


# filename = f"./UvsT.png"
# plt.savefig(filename,dpi=300)

# %%
timemask = np.where(t_model_maciek<350)

fig, ax = plt.subplots(figsize=[6,6])

# load_data = np.loadtxt("./experimentalDataQU_t_Q_U.txt",unpack=True)
# t_load,Q_load,U_load=load_data
timeInHrs = t_load_2turns * t_from_M_to_hours

sc=plt.scatter(Q_load_2turns,U_load_2turns,c=t_load_2turns,s=2,marker="*",cmap="rainbow")
xlim,ylim = auto_limits(Q_load_2turns,U_load_2turns,Q_load_2turns,U_load_2turns)
ax.scatter(Q_rotated[timemask],U_rotated[timemask],s=2,color='k')

x0, y0 = Q_load_2turns[0], U_load_2turns[0]
ax.scatter(x0, y0, s=50, marker="X", color="purple", label="t = 0.0", zorder=4)

# Values are in figure fraction coordinates: [left, bottom, width, height]
cbar_ax = fig.add_axes([0.28, 0.19, 0.6, 0.02])  # [x, y, width, height]
cbar = plt.colorbar(sc, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Time [M]")
cbar.set_ticks(np.arange(t_load_2turns[0], t_load_2turns[-1], 100))
cbar.set_ticklabels([f"{t}" for t in np.arange(t_load_2turns[0], t_load_2turns[-1], 100)])

# Use twinx() for a vertical colorbar, twiny() for a horizontal one
cax2 = cbar.ax.twiny()

# 2. Set the limits of the new axis
# The limits must correspond to the data range for the secondary labels
cax2.set_xlim(cbar.ax.get_xlim()) # Match the primary axis limits

# 3. Set custom ticks and labels for the second axis
secondary_ticks = [100, 200, 300, 400] 
secondary_labels = ['35.3', '70.6', '105.8', '141.1']
cax2.set_xticks(secondary_ticks)
cax2.set_xticklabels(secondary_labels)
cax2.set_xlabel('[minutes]') # Add a label for the second axis

# Optional: Adjust the position of the new labels
cax2.yaxis.set_ticks_position('left')
cax2.yaxis.set_label_position('left')

# Plot configuration
ax.plot(0, 0, "xk")  # Ensure it's plotted on the main axes
ax.set_xlim(xlim)
ax.set_ylim(ylim[0]-0.04,ylim[1])
ax.set_xlabel("Q", fontsize=12)
ax.set_ylabel("U", fontsize=12)
ax.grid(alpha=0.2)
ax.legend(loc='upper right', bbox_to_anchor=(1, 1),frameon=False, fontsize=12)
ax.set_title("ALMA dataset 11Apr QU Loop")


# filename = f"./QU.png"
# plt.savefig(filename,dpi=300)
# Out:
# Text(0.5, 1.0, 'ALMA dataset 11Apr QU Loop')
